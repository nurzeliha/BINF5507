# %%
# Import necessary modules
import data_preprocessor as dp
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# 1. Load the dataset
messy_data = pd.read_csv('../Data/messy_data.csv')
clean_data = messy_data.copy()
#print(clean_data.head())


# 2. Preprocess the data
#clean_data = dp.impute_missing_values(clean_data, strategy='mean')
clean_data = dp.impute_missing_values_new(clean_data)
clean_data = dp.remove_duplicates(clean_data)
#clean_data = dp.normalize_data(clean_data)
clean_data = dp.normalize_data_new(clean_data)
clean_data = dp.remove_redundant_features(clean_data)
print(clean_data.info())
print(clean_data.describe())

#to check the inconsistency
#for col in clean_data.select_dtypes(include='object').columns:
    #print(clean_data[col].unique())

# 3. Save the cleaned dataset
clean_data.to_csv('../Data/clean_data.csv', index=False)

# 4. Train and evaluate the model
dp.simple_model_new(clean_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1040 entries, 0 to 1194
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  1040 non-null   float64
#  1   a       1040 non-null   object
#  2   b       1040 non-null   float64
#  3   c       1040 non-null   float64
#  4   d       1040 non-null   object
#  5   e       1040 non-null   object
#  6   f       1040 non-null   float64
#  7   g       1040 non-null   object
#  8   h       1040 non-null   float64
#  9   i       1040 non-null   bool
#  10  j       1040 non-null   float64
#  11  k       1040 non-null   float64
#  12  l       1040 non-null   float64
#  13  m       1040 non-null   object
#  14  n       1040 non-null   float64
#  15  o       1040 non-null   float64
#  16  s       1040 non-null   object
#  17  t       1040 non-null   float64
#  18  v       1040 non-null   float64
#  19  w       1040 non-null   float64
#  20  x       1040 non-null   float64
# ...
